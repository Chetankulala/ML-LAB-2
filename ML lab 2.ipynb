# %%
import pandas as pd
import numpy as np
dt =pd.read_excel('C:\\Users\\Chetan\\OneDrive\\Documents\\lab1ML\\19CSE305_LabData_Set3.1.xlsx',sheet_name='thyroid0387_UCI')
dt
# Out:
#       RecordID  age sex onthyroxine queryonthyroxine onantithyroidmedication  \
# 0    840801013   29   F           f                f                       f
# 1    840801014   29   F           f                f                       f
# 2    840801042   41   F           f                f                       f
# 3    840803046   36   F           f                f                       f
# 4    840803047   32   F           f                f                       f
# ..         ...  ...  ..         ...              ...                     ...
# 995  841031002   41   F           f                f                       f
# 996  841031010   41   F           f                f                       f
# 997  841031030   20   F           f                f                       f
# 998  841031031   20   F           f                f                       f
# 999  841031032   73   F           f                f                       f
#
#     sick pregnant thyroidsurgery I131treatment  ... TT4measured    TT4  \
# 0      f        f              f             f  ...           f    NaN
# 1      f        f              f             f  ...           t  128.0
# 2      f        f              f             f  ...           f    NaN
# 3      f        f              f             f  ...           f    NaN
# 4      f        f              f             f  ...           f    NaN
# ..   ...      ...            ...           ...  ...         ...    ...
# 995    f        f              f             f  ...           t  148.0
# 996    f        f              f             f  ...           t    9.7
# 997    f        t              f             f  ...           f    NaN
# 998    f        f              f             f  ...           t  201.0
# 999    f        f              f             f  ...           t   85.0
#
#     T4Umeasured   T4U FTImeasured    FTI TBGmeasured   TBG  referralsource  \
# 0             f   NaN           f    NaN           f   NaN           other
# 1             f   NaN           f    NaN           f   NaN           other
# 2             f   NaN           f    NaN           t  11.0           other
# 3             f   NaN           f    NaN           t  26.0           other
# 4             f   NaN           f    NaN           t  36.0           other
# ..          ...   ...         ...    ...         ...   ...             ...
# 995           t  1.44           t  103.0           f   NaN            STMW
# 996           t  1.46           t    6.6           f   NaN           other
# 997           f   NaN           f    NaN           t  30.0           other
# 998           t  0.84           t  240.0           f   NaN             SVI
# 999           t  0.90           t   94.0           f   NaN             SVI
#
#        Condition
# 0    NOCONDITION
# 1    NOCONDITION
# 2    NOCONDITION
# 3    NOCONDITION
# 4              S
# ..           ...
# 995  NOCONDITION
# 996            F
# 997  NOCONDITION
# 998           AK
# 999  NOCONDITION
#
# [1000 rows x 31 columns]

# %%
data_type={}
x={}
column_names=dt.select_dtypes(include=['float64','int64'])
column_names=list(column_names)
i=0
columns=dt.columns
for column in column_names:
    x[column]=[dt[column].min(),dt[column].max()]
    i+=1

for column in  columns:
    if column in column_names:
        data_type[column]='quantitative'
    else:
        data_type[column]='categorical'
print(data_type)
print("")
print(x)
# Out:
# {'RecordID': 'quantitative', 'age': 'quantitative', 'sex': 'categorical', 'onthyroxine': 'categorical', 'queryonthyroxine': 'categorical', 'onantithyroidmedication': 'categorical', 'sick': 'categorical', 'pregnant': 'categorical', 'thyroidsurgery': 'categorical', 'I131treatment': 'categorical', 'queryhypothyroid': 'categorical', 'queryhyperthyroid': 'categorical', 'lithium': 'categorical', 'goitre': 'categorical', 'tumor': 'categorical', 'hypopituitary': 'categorical', 'psych': 'categorical', 'TSHmeasured': 'categorical', 'TSH': 'quantitative', 'T3measured': 'categorical', 'T3': 'quantitative', 'TT4measured': 'categorical', 'TT4': 'quantitative', 'T4Umeasured': 'categorical', 'T4U': 'quantitative', 'FTImeasured': 'categorical', 'FTI': 'quantitative', 'TBGmeasured': 'categorical', 'TBG': 'quantitative', 'referralsource': 'categorical', 'Condition': 'categorical'}
#
# {'RecordID': [840801013, 841031032], 'age': [1, 97], 'TSH': [0.05, 430.0], 'T3': [0.05, 8.599999], 'TT4': [3.0, 359.0], 'T4U': [0.2, 1.86], 'FTI': [2.5, 839.0], 'TBG': [9.299999, 53.0]}

# %%
nnull={}
for column in column_names:
    nnull[column]=dt[column].isna().sum()
print(nnull)
# Out:
# {'RecordID': 0, 'age': 0, 'TSH': 115, 'T3': 202, 'TT4': 40, 'T4U': 98, 'FTI': 98, 'TBG': 964}

# %%
variance={}
mean={}
column_names=dt.select_dtypes(include=['float64','int64'])

for column in column_names:
    variance[column] = np.var(dt[column])
    mean[column]=np.mean(dt[column])
print(variance)
mean
# Out:
# {'RecordID': 5813938991.469424, 'age': 352.205919, 'TSH': 864.3683599958953, 'T3': 0.6494457033603758, 'TT4': 1737.3178072482638, 'T4U': 0.0427871913117438, 'FTI': 3829.094722051514, 'TBG': 63.388233965277806}
# {'RecordID': 840934027.976,
#  'age': 51.509,
#  'TSH': 6.5596384079096035,
#  'T3': 1.8222431065162907,
#  'TT4': 106.44770833333334,
#  'T4U': 0.972039911308204,
#  'FTI': 114.60088691796008,
#  'TBG': 26.23055552777778}

# %%
import math

outliers={}
for column in column_names:
    count=0
    for a in dt[column]:
        z=(a-mean[column])/math.sqrt(variance[column])
        if z<0:
            z*=-1
        if z>3:
            count+=1
    if count >0:
        outliers[column]='yes'
    else:
        outliers[column]='no'
print(outliers)
# Out:
# {'RecordID': 'no', 'age': 'no', 'TSH': 'yes', 'T3': 'yes', 'TT4': 'yes', 'T4U': 'yes', 'FTI': 'yes', 'TBG': 'yes'}

# %%
for column in dt.columns:
    if column in column_names :
        if outliers[column]=='yes':
            dt[column].fillna(dt[column].median(), inplace=True)
        else:
            dt[column].fillna(dt[column].mean(), inplace=True)
    else:
        dt[column].fillna(dt[column].mode(), inplace=True)

dt
# Out:
#       RecordID  age sex onthyroxine queryonthyroxine onantithyroidmedication  \
# 0    840801013   29   F           f                f                       f
# 1    840801014   29   F           f                f                       f
# 2    840801042   41   F           f                f                       f
# 3    840803046   36   F           f                f                       f
# 4    840803047   32   F           f                f                       f
# ..         ...  ...  ..         ...              ...                     ...
# 995  841031002   41   F           f                f                       f
# 996  841031010   41   F           f                f                       f
# 997  841031030   20   F           f                f                       f
# 998  841031031   20   F           f                f                       f
# 999  841031032   73   F           f                f                       f
#
#     sick pregnant thyroidsurgery I131treatment  ... TT4measured    TT4  \
# 0      f        f              f             f  ...           f  103.0
# 1      f        f              f             f  ...           t  128.0
# 2      f        f              f             f  ...           f  103.0
# 3      f        f              f             f  ...           f  103.0
# 4      f        f              f             f  ...           f  103.0
# ..   ...      ...            ...           ...  ...         ...    ...
# 995    f        f              f             f  ...           t  148.0
# 996    f        f              f             f  ...           t    9.7
# 997    f        t              f             f  ...           f  103.0
# 998    f        f              f             f  ...           t  201.0
# 999    f        f              f             f  ...           t   85.0
#
#     T4Umeasured   T4U FTImeasured    FTI TBGmeasured   TBG  referralsource  \
# 0             f  0.96           f  106.0           f  25.5           other
# 1             f  0.96           f  106.0           f  25.5           other
# 2             f  0.96           f  106.0           t  11.0           other
# 3             f  0.96           f  106.0           t  26.0           other
# 4             f  0.96           f  106.0           t  36.0           other
# ..          ...   ...         ...    ...         ...   ...             ...
# 995           t  1.44           t  103.0           f  25.5            STMW
# 996           t  1.46           t    6.6           f  25.5           other
# 997           f  0.96           f  106.0           t  30.0           other
# 998           t  0.84           t  240.0           f  25.5             SVI
# 999           t  0.90           t   94.0           f  25.5             SVI
#
#        Condition
# 0    NOCONDITION
# 1    NOCONDITION
# 2    NOCONDITION
# 3    NOCONDITION
# 4              S
# ..           ...
# 995  NOCONDITION
# 996            F
# 997  NOCONDITION
# 998           AK
# 999  NOCONDITION
#
# [1000 rows x 31 columns]

# %%
from sklearn.preprocessing import StandardScaler
Standard_Scaler=StandardScaler()
dt[column_names] = Standard_Scaler.fit_transform(dt[column_names])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23708\1157749903.py in ?()
#       1 from sklearn.preprocessing import StandardScaler
#       2 Standard_Scaler=StandardScaler()
# ----> 3 dt[column_names] = Standard_Scaler.fit_transform(dt[column_names])
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py in ?(self, key)
#    3744             return self._slice(indexer, axis=0)
#    3745
#    3746         # Do we have a (boolean) DataFrame?
#    3747         if isinstance(key, DataFrame):
# -> 3748             return self.where(key)
#    3749
#    3750         # Do we have a (boolean) 1d indexer?
#    3751         if com.is_bool_indexer(key):
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py in ?(self, cond, other, inplace, axis, level)
#   11523         inplace: bool = False,
#   11524         axis: Axis | None = None,
#   11525         level: Level = None,
#   11526     ) -> DataFrame | None:
# > 11527         return super().where(
#   11528             cond,
#   11529             other,
#   11530             inplace=inplace,
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, cond, other, inplace, axis, level)
#    9929         3  True  True
#    9930         4  True  True
#    9931         """
#    9932         other = common.apply_if_callable(other, self)
# -> 9933         return self._where(cond, other, inplace, axis, level)
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, cond, other, inplace, axis, level)
#    9650                     raise ValueError(msg.format(dtype=cond.dtype))
#    9651             else:
#    9652                 for _dt in cond.dtypes:
#    9653                     if not is_bool_dtype(_dt):
# -> 9654                         raise ValueError(msg.format(dtype=_dt))
#    9655         else:
#    9656             # GH#21947 we have an empty DataFrame/Series, could be object-dtype
#    9657             cond = cond.astype(bool)
#
# ValueError: Boolean array expected for the condition, not int64
